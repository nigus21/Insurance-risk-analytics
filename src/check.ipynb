# %%
import pandas as pd

df = pd.read_csv("../data/processed/clean_data.csv")
print(df.columns.tolist())
# Out:
# C:\Users\Dibekulu\AppData\Local\Temp\ipykernel_12244\2672554416.py:3: DtypeWarning: Columns (11,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/clean_data.csv")
# ...
